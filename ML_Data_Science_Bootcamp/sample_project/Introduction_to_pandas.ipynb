# %%
import pandas as pd

# %%
#2 main datatypes
series = pd.Series(["BMW", "Toyota", "Honda"])
series_2 = pd.Series(data=["BMW", "Toyota", "Honda"], index=["1000", "2000", "3000"])

# %%
series
series_2
# Out:
# 1000       BMW
# 2000    Toyota
# 3000     Honda
# dtype: object

# %%
colours = pd.Series(["red", "blue", "white"])
colours
# Out:
# 0      red
# 1     blue
# 2    white
# dtype: object

# %%
#DataFrame = 2-dimensional
car_data = pd.DataFrame({"Car make": series, "Colour": colours})
car_data
# Out:
#   Car make Colour
# 0      BMW    red
# 1   Toyota   blue
# 2    Honda  white

# %%
data = {
    "Name": ['Alice', 'Bob', 'JAck'],
    "Age": [22,23,34],
    "Pass": [True, False, True]
}
students = pd.DataFrame(data)
students
# Out:
#     Name  Age   Pass
# 0  Alice   22   True
# 1    Bob   23  False
# 2   JAck   34   True

# %%
students.head()
# Out:
#     Name  Age   Pass
# 0  Alice   22   True
# 1    Bob   23  False
# 2   JAck   34   True

# %%
student_name = students["Name"]
student_name
# Out:
# 0    Alice
# 1      Bob
# 2     JAck
# Name: Name, dtype: object

# %%
students.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Name    3 non-null      object
#  1   Age     3 non-null      int64
#  2   Pass    3 non-null      bool
# dtypes: bool(1), int64(1), object(1)
# memory usage: 183.0+ bytes

# %%
#Import Data
car_sales = pd.read_csv("car-sales.csv")
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_sales.to_csv("exported-car-sales.csv", index=False)

# %%
expordet_car_sales = pd.read_csv("exported-car-sales.csv")
expordet_car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# Describe DATA

# %%
##Attributes
car_sales.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
car_columns = car_sales.columns

# %%
car_columns
# Out:
# Index(['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price'], dtype='object')

# %%
car_sales.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %%
car_sales.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
car_sales.mean(numeric_only=True)
# Out:
# Odometer (KM)    78601.4
# Doors                4.0
# dtype: float64

# %%
car_sales.sum()
# Out:
# Make             ToyotaHondaToyotaBMWNissanToyotaHondaHondaToyo...
# Colour               WhiteRedBlueBlackWhiteGreenBlueBlueWhiteWhite
# Odometer (KM)                                               786014
# Doors                                                           40
# Price            $4,000.00$5,000.00$7,000.00$22,000.00$3,500.00...
# dtype: object

# %%
car_sales["Odometer (KM)"].sum()
# Out:
# np.int64(786014)

# %%
len(car_sales)
# Out:
# 10

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %% [markdown]
# ## Viewing and secting data

# %%
car_sales.head()
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
car_sales.head(8)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00

# %%
car_sales.tail()
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %% [markdown]
# ## .loc & .iloc

# %%
animals = pd.Series(["cat", "dog", "bird", "panda", "snake"], index=[0,3,5,8,3])
animals
# Out:
# 0      cat
# 3      dog
# 5     bird
# 8    panda
# 3    snake
# dtype: object

# %%
animals.loc[3]
# Out:
# 3      dog
# 3    snake
# dtype: object

# %%
animals.iloc[3]
# Out:
# 'panda'

# %%
car_sales.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
animals.iloc[:3]
# Out:
# 0     cat
# 3     dog
# 5    bird
# dtype: object

# %%
car_sales.iloc[:3]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 1   Honda    Red          87899      4  $5,000.00
# 2  Toyota   Blue          32549      3  $7,000.00

# %%
car_sales["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales.Make
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
car_sales[car_sales["Make"] == "Toyota"]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 2  Toyota   Blue          32549      3  $7,000.00
# 5  Toyota  Green          99213      4  $4,500.00
# 8  Toyota  White          60000      4  $6,250.00

# %%
car_sales[car_sales["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   400000
# 1   Honda    Red          87899      4   500000
# 2  Toyota   Blue          32549      3   700000
# 3     BMW  Black          11179      5  2200000
# 4  Nissan  White         213095      4   350000
# 5  Toyota  Green          99213      4   450000
# 6   Honda   Blue          45698      4   750000
# 7   Honda   Blue          54738      4   700000
# 8  Toyota  White          60000      4   625000
# 9  Nissan  White          31600      4   970000

# %%
pd.crosstab(car_sales["Make"], car_sales["Doors"], margins=True)
# Out:
# Doors   3  4  5  All
# Make
# BMW     0  0  1    1
# Honda   0  3  0    3
# Nissan  0  2  0    2
# Toyota  1  3  0    4
# All     1  8  1   10

# %%
car_sales.groupby(["Make"]).mean(numeric_only=True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline

# %%
car_sales["Odometer (KM)"].plot()
# Out:
# <Axes: >

# %%
car_sales["Odometer (KM)"].plot(kind="hist")
# Out:
# <Axes: ylabel='Frequency'>

# %%
car_sales["Odometer (KM)"].hist()
# Out:
# <Axes: >

# %%
car_sales['Price'].dtype
# Out:
# dtype('int64')

# %%
car_sales = pd.read_csv("car-sales.csv")

# %%
car_sales["Price"] = car_sales["Price"].str.replace(r'[\$,]', '', regex=True).astype(float)

# %%
car_sales.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     float64
# dtypes: float64(1), int64(2), object(2)
# memory usage: 532.0+ bytes

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Price"].plot()
# Out:
# <Axes: >

# %% [markdown]
# ## Manipulating Data

# %%
car_sales["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  Toyota  White         150043      4   4000.0
# 1   Honda    Red          87899      4   5000.0
# 2  Toyota   Blue          32549      3   7000.0
# 3     BMW  Black          11179      5  22000.0
# 4  Nissan  White         213095      4   3500.0
# 5  Toyota  Green          99213      4   4500.0
# 6   Honda   Blue          45698      4   7500.0
# 7   Honda   Blue          54738      4   7000.0
# 8  Toyota  White          60000      4   6250.0
# 9  Nissan  White          31600      4   9700.0

# %%
car_sales["Make"] = car_sales["Make"].str.lower()

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price
# 0  toyota  White         150043      4   4000.0
# 1   honda    Red          87899      4   5000.0
# 2  toyota   Blue          32549      3   7000.0
# 3     bmw  Black          11179      5  22000.0
# 4  nissan  White         213095      4   3500.0
# 5  toyota  Green          99213      4   4500.0
# 6   honda   Blue          45698      4   7500.0
# 7   honda   Blue          54738      4   7000.0
# 8  toyota  White          60000      4   6250.0
# 9  nissan  White          31600      4   9700.0

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing["Odometer"].fillna(car_sales_missing["Odometer"].mean(numeric_only=True), inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500
# 6   Honda    NaN   92302.666667    4.0   $7,500
# 7   Honda   Blue   92302.666667    4.0      NaN
# 8  Toyota  White   60000.000000    NaN      NaN
# 9     NaN  White   31600.000000    4.0   $9,700

# %%
car_sales_missing.dropna(inplace=True)

# %%
car_sales_missing
# Out:
#      Make Colour       Odometer  Doors    Price
# 0  Toyota  White  150043.000000    4.0   $4,000
# 1   Honda    Red   87899.000000    4.0   $5,000
# 2  Toyota   Blue   92302.666667    3.0   $7,000
# 3     BMW  Black   11179.000000    5.0  $22,000
# 4  Nissan  White  213095.000000    4.0   $3,500
# 5  Toyota  Green   92302.666667    4.0   $4,500

# %%
car_sales_missing = pd.read_csv("car-sales-missing-data.csv")
car_sales_missing
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 2  Toyota   Blue       NaN    3.0   $7,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500
# 5  Toyota  Green       NaN    4.0   $4,500
# 6   Honda    NaN       NaN    4.0   $7,500
# 7   Honda   Blue       NaN    4.0      NaN
# 8  Toyota  White   60000.0    NaN      NaN
# 9     NaN  White   31600.0    4.0   $9,700

# %%
car_sales_missing_dropped = car_sales_missing.dropna()

# %%
car_sales_missing_dropped
# Out:
#      Make Colour  Odometer  Doors    Price
# 0  Toyota  White  150043.0    4.0   $4,000
# 1   Honda    Red   87899.0    4.0   $5,000
# 3     BMW  Black   11179.0    5.0  $22,000
# 4  Nissan  White  213095.0    4.0   $3,500

# %%
car_sales_missing_dropped.to_csv("car_sales_missing_dropped.csv")

# %%
#Column from Series
seats_column = pd.Series([5,5,5,5,5])

# %%
car_sales["Seats"] = seats_column

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    NaN
# 6   honda   Blue          45698      4   7500.0    NaN
# 7   honda   Blue          54738      4   7000.0    NaN
# 8  toyota  White          60000      4   6250.0    NaN
# 9  nissan  White          31600      4   9700.0    NaN

# %%
car_sales["Seats"].fillna(5, inplace=True)

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats
# 0  toyota  White         150043      4   4000.0    5.0
# 1   honda    Red          87899      4   5000.0    5.0
# 2  toyota   Blue          32549      3   7000.0    5.0
# 3     bmw  Black          11179      5  22000.0    5.0
# 4  nissan  White         213095      4   3500.0    5.0
# 5  toyota  Green          99213      4   4500.0    5.0
# 6   honda   Blue          45698      4   7500.0    5.0
# 7   honda   Blue          54738      4   7000.0    5.0
# 8  toyota  White          60000      4   6250.0    5.0
# 9  nissan  White          31600      4   9700.0    5.0

# %%
## Column from Python ==List==
fuel_economy = [7.3, 5.6, 5.0, 8.6, 7.7, 6.6, 8.7, 7.9, 7.0, 6.9]
car_sales["Fuel per 100 KM"] = fuel_economy

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM
# 0  toyota  White         150043      4   4000.0    5.0              7.3
# 1   honda    Red          87899      4   5000.0    5.0              5.6
# 2  toyota   Blue          32549      3   7000.0    5.0              5.0
# 3     bmw  Black          11179      5  22000.0    5.0              8.6
# 4  nissan  White         213095      4   3500.0    5.0              7.7
# 5  toyota  Green          99213      4   4500.0    5.0              6.6
# 6   honda   Blue          45698      4   7500.0    5.0              8.7
# 7   honda   Blue          54738      4   7000.0    5.0              7.9
# 8  toyota  White          60000      4   6250.0    5.0              7.0
# 9  nissan  White          31600      4   9700.0    5.0              6.9

# %%
car_sales["Total fuel used"] = car_sales["Odometer (KM)"]/100 * car_sales["Fuel per 100 KM"]

# %%
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  toyota  White         150043      4   4000.0    5.0              7.3
# 1   honda    Red          87899      4   5000.0    5.0              5.6
# 2  toyota   Blue          32549      3   7000.0    5.0              5.0
# 3     bmw  Black          11179      5  22000.0    5.0              8.6
# 4  nissan  White         213095      4   3500.0    5.0              7.7
# 5  toyota  Green          99213      4   4500.0    5.0              6.6
# 6   honda   Blue          45698      4   7500.0    5.0              8.7
# 7   honda   Blue          54738      4   7000.0    5.0              7.9
# 8  toyota  White          60000      4   6250.0    5.0              7.0
# 9  nissan  White          31600      4   9700.0    5.0              6.9
#
#    Total fuel used
# 0        10953.139
# 1         4922.344
# 2         1627.450
# 3          961.394
# 4        16408.315
# 5         6548.058
# 6         3975.726
# ...

# %%
#Create a column from a single value
car_sales["Number of wheels"] = 4
car_sales
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 0  toyota  White         150043      4   4000.0    5.0              7.3
# 1   honda    Red          87899      4   5000.0    5.0              5.6
# 2  toyota   Blue          32549      3   7000.0    5.0              5.0
# 3     bmw  Black          11179      5  22000.0    5.0              8.6
# 4  nissan  White         213095      4   3500.0    5.0              7.7
# 5  toyota  Green          99213      4   4500.0    5.0              6.6
# 6   honda   Blue          45698      4   7500.0    5.0              8.7
# 7   honda   Blue          54738      4   7000.0    5.0              7.9
# 8  toyota  White          60000      4   6250.0    5.0              7.0
# 9  nissan  White          31600      4   9700.0    5.0              6.9
#
#    Total fuel used  Number of wheels
# 0        10953.139                 4
# 1         4922.344                 4
# 2         1627.450                 4
# ...

# %%
car_sales["Passed road safety"] = True
car_sales.dtypes
# Out:
# Make                   object
# Colour                 object
# Odometer (KM)           int64
# Doors                   int64
# Price                 float64
# Seats                 float64
# Fuel per 100 KM       float64
# Total fuel used       float64
# Number of wheels        int64
# Passed road safety       bool
# dtype: object

# %%
car_sales_shuffled = car_sales.sample(frac=1)

# %%
car_sales_shuffled
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Fuel per 100 KM  \
# 9  nissan  White          31600      4   9700.0    5.0              6.9
# 2  toyota   Blue          32549      3   7000.0    5.0              5.0
# 6   honda   Blue          45698      4   7500.0    5.0              8.7
# 5  toyota  Green          99213      4   4500.0    5.0              6.6
# 3     bmw  Black          11179      5  22000.0    5.0              8.6
# 4  nissan  White         213095      4   3500.0    5.0              7.7
# 0  toyota  White         150043      4   4000.0    5.0              7.3
# 7   honda   Blue          54738      4   7000.0    5.0              7.9
# 1   honda    Red          87899      4   5000.0    5.0              5.6
# 8  toyota  White          60000      4   6250.0    5.0              7.0
#
#    Total fuel used  Number of wheels  Passed road safety
# 9         2180.400                 4                True
# 2         1627.450                 4                True
# ...

# %%
#Only 20% of the data
car_sales_shuffled.sample(frac=0.2)
# Out:
#      Make Colour  Odometer (KM)  Doors   Price  Seats  Fuel per 100 KM  \
# 2  toyota   Blue          32549      3  7000.0    5.0              5.0
# 1   honda    Red          87899      4  5000.0    5.0              5.6
#
#    Total fuel used  Number of wheels  Passed road safety
# 2         1627.450                 4                True
# 1         4922.344                 4                True

# %%
car_sales = car_sales.reset_index()
car_sales
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0      6   honda   Blue          45698      4   7500.0    5.0
# 1      4  nissan  White         213095      4   3500.0    5.0
# 2      1   honda    Red          87899      4   5000.0    5.0
# 3      3     bmw  Black          11179      5  22000.0    5.0
# 4      7   honda   Blue          54738      4   7000.0    5.0
# 5      8  toyota  White          60000      4   6250.0    5.0
# 6      0  toyota  White         150043      4   4000.0    5.0
# 7      9  nissan  White          31600      4   9700.0    5.0
# 8      5  toyota  Green          99213      4   4500.0    5.0
# 9      2  toyota   Blue          32549      3   7000.0    5.0
#
#    Fuel per 100 KM  Total fuel used  Number of wheels  Passed road safety
# 0              8.7         3975.726                 4                True
# 1              7.7        16408.315                 4                True
# ...

# %%
car_sales
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0      6   honda   Blue          45698      4   7500.0    5.0
# 1      4  nissan  White         213095      4   3500.0    5.0
# 2      1   honda    Red          87899      4   5000.0    5.0
# 3      3     bmw  Black          11179      5  22000.0    5.0
# 4      7   honda   Blue          54738      4   7000.0    5.0
# 5      8  toyota  White          60000      4   6250.0    5.0
# 6      0  toyota  White         150043      4   4000.0    5.0
# 7      9  nissan  White          31600      4   9700.0    5.0
# 8      5  toyota  Green          99213      4   4500.0    5.0
# 9      2  toyota   Blue          32549      3   7000.0    5.0
#
#    Fuel per 100 KM  Total fuel used  Number of wheels  Passed road safety
# 0              8.7         3975.726                 4                True
# 1              7.7        16408.315                 4                True
# ...

# %%
car_sales["Odometer (KM)"] = car_sales["Odometer (KM)"].apply(lambda x: x/1.6)
car_sales
# Out:
#    index    Make Colour  Odometer (KM)  Doors    Price  Seats  \
# 0      6   honda   Blue      28561.250      4   7500.0    5.0
# 1      4  nissan  White     133184.375      4   3500.0    5.0
# 2      1   honda    Red      54936.875      4   5000.0    5.0
# 3      3     bmw  Black       6986.875      5  22000.0    5.0
# 4      7   honda   Blue      34211.250      4   7000.0    5.0
# 5      8  toyota  White      37500.000      4   6250.0    5.0
# 6      0  toyota  White      93776.875      4   4000.0    5.0
# 7      9  nissan  White      19750.000      4   9700.0    5.0
# 8      5  toyota  Green      62008.125      4   4500.0    5.0
# 9      2  toyota   Blue      20343.125      3   7000.0    5.0
#
#    Fuel per 100 KM  Total fuel used  Number of wheels  Passed road safety
# 0              8.7         3975.726                 4                True
# 1              7.7        16408.315                 4                True
# ...

# %%
## Rename a Column
car_sales = car_sales.rename(columns={"Odometer (KM)":"Odometer"})

# %%
car_sales
# Out:
#    index    Make Colour    Odometer  Doors    Price  Seats  Fuel per 100 KM  \
# 0      6   honda   Blue   28561.250      4   7500.0    5.0              8.7
# 1      4  nissan  White  133184.375      4   3500.0    5.0              7.7
# 2      1   honda    Red   54936.875      4   5000.0    5.0              5.6
# 3      3     bmw  Black    6986.875      5  22000.0    5.0              8.6
# 4      7   honda   Blue   34211.250      4   7000.0    5.0              7.9
# 5      8  toyota  White   37500.000      4   6250.0    5.0              7.0
# 6      0  toyota  White   93776.875      4   4000.0    5.0              7.3
# 7      9  nissan  White   19750.000      4   9700.0    5.0              6.9
# 8      5  toyota  Green   62008.125      4   4500.0    5.0              6.6
# 9      2  toyota   Blue   20343.125      3   7000.0    5.0              5.0
#
#    Total fuel used  Number of wheels  Passed road safety
# 0         3975.726                 4                True
# ...
